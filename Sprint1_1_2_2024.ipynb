# %% [markdown]
# <a href="https://colab.research.google.com/github/Passakorn-V/DS_Sprint1/blob/main/Sprint1_1_2_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install --upgrade pymongo[srv]
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (676 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 5.7 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.6.3
# Requirement already satisfied: dnspython in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.10/dist-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo[srv]) (2.6.1)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://kong:2GgNZ7V0V0q5Go9d@botnoivoiceprod.f4igi.mongodb.net/?retryWrites=true&readPreference=secondary&readPreferenceTags=nodeType:ANALYTICS&w=majority&appName=botnoivoiceprod"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
paymentdb = client['prod-tts-payment']

# %%
import pandas as pd

# %%
paymentdb.payment.find_one()
# Out:
# {'_id': ObjectId('612e3e206bcbfac605a1c8aa'),
#  'user_id': 'U8530610030c64cc1843fd0f95b5f2758',
#  'package_id': 150,
#  'price': 50,
#  'qrcode': '00020101021230820016A0000006770101120115010753600037404021500000220300124303204300012521083121351253037645402505802TH5909LUGENTPAY621207084300012563040936',
#  'transactionid': '01075360003740400000220300124343000125210831213512',
#  'datetime': '2021-08-31',
#  'ref1': 'WI9FIRQJNZGK8Q15Z0M6',
#  'status': False}

# %%
df_pay  = pd.DataFrame(paymentdb.payment.find())
df_pay
# Out:
#                              _id                            user_id  \
# 0       612e3e206bcbfac605a1c8aa  U8530610030c64cc1843fd0f95b5f2758
# 1       612ee88ce827b44913887b68  U1d068ce57105d8463132691e9c2a4c3e
# 2       613afeffbd6b51f5666f4dca  U3bdae9df091601f970a61ff8e5d5a72a
# 3       613f26db233bb14db8f57c5e  U10e1ae0a6e2e2102ce01e8b3aca82433
# 4       613f2949233bb14db8f57c60  U3bdae9df091601f970a61ff8e5d5a72a
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price                                             qrcode  \
# 0             150    50  00020101021230820016A0000006770101120115010753...
# 1             150    50  00020101021230820016A0000006770101120115010753...
# 2             150    50  00020101021230820016A0000006770101120115010753...
# 3         credits     9  00020101021230820016A0000006770101120115010753...
# 4         credits     1  00020101021230820016A0000006770101120115010753...
# ...           ...   ...                                                ...
# 543071    pack_99    99                                                NaN
# 543072   pack_299   199                                                NaN
# 543073    pack_99    99                                                NaN
# 543074          1   500
# 543075     credit    13                                                NaN
#
#                                             transactionid  \
# 0       0107536000374040000022030012434300012521083121...
# 1       0107536000374040000022030012434300012521090109...
# 2       0107536000374040000022030012434300012521091013...
# 3       0107536000374040000022030012434300012521091317...
# 4       0107536000374040000022030012434300012521091317...
# ...                                                   ...
# 543071                                                NaN
# 543072                                                NaN
# 543073                                                NaN
# 543074
# 543075                                                NaN
#
#                    datetime                  ref1 status  point promotion  \
# 0                2021-08-31  WI9FIRQJNZGK8Q15Z0M6  False    NaN       NaN
# 1                2021-09-01  TJCRE95Q3JB73MXDJ8U3  False    NaN       NaN
# 2                2021-09-10  CW2AEP6Q2EMW3S45KFSN  False    NaN       NaN
# 3                2021-09-13  H93RS1DFP8CWQIFAN2ED  False     18         0
# 4                2021-09-13  0QEZB1JQBB5EY5W0CRFU  False      3         0
# ...                     ...                   ...    ...    ...       ...
# 543071  2024-04-11 16:36:35                   NaN   True   4100       NaN
# 543072  2024-04-11 17:02:43                   NaN   True  12500       NaN
# 543073  2024-04-11 17:19:19                   NaN   True   4100       NaN
# 543074  2024-04-11 17:21:51                          NaN  10000         0
# 543075  2024-04-11 17:55:38                   NaN   True    520       NaN
#
#                        actual_time sale_code_name package_sub  action  \
# 0                              NaN            NaN         NaN     NaN
# 1                              NaN            NaN         NaN     NaN
# 2                              NaN            NaN         NaN     NaN
# 3                              NaN            NaN         NaN     NaN
# 4                              NaN            NaN         NaN     NaN
# ...                            ...            ...         ...     ...
# 543071  2024-04-11 16:36:35.034000                        NaN     NaN
# 543072  2024-04-11 17:02:43.549000                        NaN     NaN
# 543073  2024-04-11 17:19:19.046000                        NaN     NaN
# 543074  2024-04-11 17:21:51.998000                        NaN  add_on
# 543075  2024-04-11 17:55:38.107000                        NaN     NaN
#
#        subscription sub_id
# 0               NaN    NaN
# 1               NaN    NaN
# 2               NaN    NaN
# 3               NaN    NaN
# 4               NaN    NaN
# ...             ...    ...
# 543071         Free    NaN
# 543072         Free    NaN
# 543073         Free    NaN
# 543074          NaN    NaN
# 543075         Free    NaN
#
# [543076 rows x 17 columns]

# %%
paymentdb.message.find_one()
# Out:
# {'_id': ObjectId('612e4174bda79b4dffbfeb84'),
#  'user_id': 'U8530610030c64cc1843fd0f95b5f2758',
#  'message': 'สวัสดีครับ',
#  'datetime': '2021-08-31 21:49:24'}

# %%
df_msg = pd.DataFrame(paymentdb.message.find())
df_msg
# Out:
#                               _id                            user_id  \
# 0        612e4174bda79b4dffbfeb84  U8530610030c64cc1843fd0f95b5f2758
# 1        612e4174952575b7a2c366c1  U8530610030c64cc1843fd0f95b5f2758
# 2        612e41749ac449ff6262dcc0  U8530610030c64cc1843fd0f95b5f2758
# 3        612e4174ea19c311d95c33b2  U8530610030c64cc1843fd0f95b5f2758
# 4        612e4174bda79b4dffbfeb85  U8530610030c64cc1843fd0f95b5f2758
# ...                           ...                                ...
# 3309847  6617c2d41133cbc3e61ba060       li7WxCoa9LdwGLhmzrFilsjUCsu1
# 3309848  6617c2d5c8c16df47362cc67       Burd7NHMZvZwWQIjj114Z3gpIqA3
# 3309849  6617c2d7a3dddc8cf3cff22d  U591e3bd8bb1108c417696f11a0ad1911
# 3309850  6617c2de6463d2b14340d925       osNbSUtz0YZqr6V09WWcPmbuaYQ2
# 3309851  6617c2e5a3958e3769a607e7       kiNTFaWLKjVCYeriITipN2yPkhx1
#
#                                                    message  \
# 0                                               สวัสดีครับ
# 1                                               สวัสดีครับ
# 2                                               สวัสดีครับ
# 3                                               สวัสดีครับ
# 4                                               สวัสดีครับ
# ...                                                    ...
# 3309847  สวัสดีเช้าวันศุกร์ที่12เมษายน2567พบกันเช่นเคยก...
# 3309848  คำถามที่ 2\nบัวลอยใบเตยทำอย่างไร\nเด็ก ๆ ร่วมก...
# 3309849  กดครับ....ถ้าเราจะเอาริงค์เฟรมเข้าเราจะต้องกดส...
# 3309850                   ตำนานท้าวเวสสุวันโดยตำนานสามพิพบ
# 3309851  หลังจากที่TikTokและYoutubeได้ติดป้ายกำกับคอนเท...
#
#                            datetime   channel count speaker  url audio_id  \
# 0               2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN
# 1               2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN
# 2               2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN
# 3               2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN
# 4               2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN
# ...                             ...       ...   ...     ...  ...      ...
# 3309847  2024-04-11 18:00:36.635883      play   346   perce  NaN    INUIZ
# 3309848         2024-04-11 18:00:37  download   160       1  NaN      NaN
# 3309849  2024-04-11 18:00:39.256379      play    67    kong  NaN    OQJOE
# 3309850  2024-04-11 18:00:46.555775  download    32  flower  NaN    DJVZE
# 3309851  2024-04-11 18:00:53.676072  download   259  jaonai  NaN    BGTLL
#
#            page provider
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 3309847  studio      NaN
# 3309848     NaN    canva
# 3309849  studio      NaN
# 3309850     NaN      NaN
# 3309851     NaN      NaN
#
# [3309852 rows x 11 columns]

# %%
df_pay  = pd.DataFrame(paymentdb.payment.find())
df_pay
# Out:
#                              _id                            user_id  \
# 0       612e3e206bcbfac605a1c8aa  U8530610030c64cc1843fd0f95b5f2758
# 1       612ee88ce827b44913887b68  U1d068ce57105d8463132691e9c2a4c3e
# 2       613afeffbd6b51f5666f4dca  U3bdae9df091601f970a61ff8e5d5a72a
# 3       613f26db233bb14db8f57c5e  U10e1ae0a6e2e2102ce01e8b3aca82433
# 4       613f2949233bb14db8f57c60  U3bdae9df091601f970a61ff8e5d5a72a
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price                                             qrcode  \
# 0             150    50  00020101021230820016A0000006770101120115010753...
# 1             150    50  00020101021230820016A0000006770101120115010753...
# 2             150    50  00020101021230820016A0000006770101120115010753...
# 3         credits     9  00020101021230820016A0000006770101120115010753...
# 4         credits     1  00020101021230820016A0000006770101120115010753...
# ...           ...   ...                                                ...
# 543071    pack_99    99                                                NaN
# 543072   pack_299   199                                                NaN
# 543073    pack_99    99                                                NaN
# 543074          1   500
# 543075     credit    13                                                NaN
#
#                                             transactionid  \
# 0       0107536000374040000022030012434300012521083121...
# 1       0107536000374040000022030012434300012521090109...
# 2       0107536000374040000022030012434300012521091013...
# 3       0107536000374040000022030012434300012521091317...
# 4       0107536000374040000022030012434300012521091317...
# ...                                                   ...
# 543071                                                NaN
# 543072                                                NaN
# 543073                                                NaN
# 543074
# 543075                                                NaN
#
#                    datetime                  ref1 status  point promotion  \
# 0                2021-08-31  WI9FIRQJNZGK8Q15Z0M6  False    NaN       NaN
# 1                2021-09-01  TJCRE95Q3JB73MXDJ8U3  False    NaN       NaN
# 2                2021-09-10  CW2AEP6Q2EMW3S45KFSN  False    NaN       NaN
# 3                2021-09-13  H93RS1DFP8CWQIFAN2ED  False     18         0
# 4                2021-09-13  0QEZB1JQBB5EY5W0CRFU  False      3         0
# ...                     ...                   ...    ...    ...       ...
# 543071  2024-04-11 16:36:35                   NaN   True   4100       NaN
# 543072  2024-04-11 17:02:43                   NaN   True  12500       NaN
# 543073  2024-04-11 17:19:19                   NaN   True   4100       NaN
# 543074  2024-04-11 17:21:51                          NaN  10000         0
# 543075  2024-04-11 17:55:38                   NaN   True    520       NaN
#
#                        actual_time sale_code_name package_sub  action  \
# 0                              NaN            NaN         NaN     NaN
# 1                              NaN            NaN         NaN     NaN
# 2                              NaN            NaN         NaN     NaN
# 3                              NaN            NaN         NaN     NaN
# 4                              NaN            NaN         NaN     NaN
# ...                            ...            ...         ...     ...
# 543071  2024-04-11 16:36:35.034000                        NaN     NaN
# 543072  2024-04-11 17:02:43.549000                        NaN     NaN
# 543073  2024-04-11 17:19:19.046000                        NaN     NaN
# 543074  2024-04-11 17:21:51.998000                        NaN  add_on
# 543075  2024-04-11 17:55:38.107000                        NaN     NaN
#
#        subscription sub_id
# 0               NaN    NaN
# 1               NaN    NaN
# 2               NaN    NaN
# 3               NaN    NaN
# 4               NaN    NaN
# ...             ...    ...
# 543071         Free    NaN
# 543072         Free    NaN
# 543073         Free    NaN
# 543074          NaN    NaN
# 543075         Free    NaN
#
# [543076 rows x 17 columns]

# %%
# แปลงคอลัมน์ datetime เป็น string
df_pay['datetime'] = df_pay['datetime'].astype(str)

# แยกวันที่และเวลาออกจากกัน
df_pay['datetime'] = df_pay['datetime'].str.split(' ')

# เก็บเฉพาะวันที่
df_pay['date'] = df_pay['datetime'].str[0]

# เก็บเฉพาะเวลา
df_pay['time'] = df_pay['datetime'].str[1]

# แปลงวันที่เป็นรูปแบบ datetime
df_pay['date'] = pd.to_datetime(df_pay['date'])

# แปลงเวลาเป็นรูปแบบ datetime
df_pay['time'] = pd.to_datetime(df_pay['time'])

# รวมวันที่และเวลาเข้าด้วยกัน
df_pay['datetime'] = pd.to_datetime(df_pay['date'].dt.strftime('%Y-%m-%d') + ' ' + df_pay['time'].dt.strftime('%H:%M:%S'))

# ลบ columns 'date' และ 'time' ที่ไม่จำเป็น
df_pay.drop(columns=['date', 'time'], inplace=True)
# Out:
# <ipython-input-10-027408bf537c>:17: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_pay['time'] = pd.to_datetime(df_pay['time'])

# %%
# แปลงคอลัมน์ datetime เป็น string
df_pay['actual_time'] = df_pay['actual_time'].astype(str)

# แยกวันที่และเวลาออกจากกัน
df_pay['actual_time'] = df_pay['actual_time'].str.split(' ')

# เก็บเฉพาะวันที่
df_pay['date'] = df_pay['actual_time'].str[0]

# เก็บเฉพาะเวลา
df_pay['time'] = df_pay['actual_time'].str[1]

# แปลงวันที่เป็นรูปแบบ datetime
df_pay['date'] = pd.to_datetime(df_pay['date'])

# แปลงเวลาเป็นรูปแบบ datetime
df_pay['time'] = pd.to_datetime(df_pay['time'])

# ตัดมิลลิวินาทีออกจากเวลา
df_pay['time'] = df_pay['time'].dt.floor('s')

# รวมวันที่และเวลาเข้าด้วยกัน
df_pay['actual_time'] = pd.to_datetime(df_pay['date'].dt.strftime('%Y-%m-%d') + ' ' + df_pay['time'].dt.strftime('%H:%M:%S'))

# ลบ columns 'date' และ 'time' ที่ไม่จำเป็น
df_pay.drop(columns=['date', 'time'], inplace=True)
# Out:
# <ipython-input-11-6a235d5d2f2c>:17: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_pay['time'] = pd.to_datetime(df_pay['time'])

# %%
df_pay
# Out:
#                              _id                            user_id  \
# 0       612e3e206bcbfac605a1c8aa  U8530610030c64cc1843fd0f95b5f2758
# 1       612ee88ce827b44913887b68  U1d068ce57105d8463132691e9c2a4c3e
# 2       613afeffbd6b51f5666f4dca  U3bdae9df091601f970a61ff8e5d5a72a
# 3       613f26db233bb14db8f57c5e  U10e1ae0a6e2e2102ce01e8b3aca82433
# 4       613f2949233bb14db8f57c60  U3bdae9df091601f970a61ff8e5d5a72a
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price                                             qrcode  \
# 0             150    50  00020101021230820016A0000006770101120115010753...
# 1             150    50  00020101021230820016A0000006770101120115010753...
# 2             150    50  00020101021230820016A0000006770101120115010753...
# 3         credits     9  00020101021230820016A0000006770101120115010753...
# 4         credits     1  00020101021230820016A0000006770101120115010753...
# ...           ...   ...                                                ...
# 543071    pack_99    99                                                NaN
# 543072   pack_299   199                                                NaN
# 543073    pack_99    99                                                NaN
# 543074          1   500
# 543075     credit    13                                                NaN
#
#                                             transactionid            datetime  \
# 0       0107536000374040000022030012434300012521083121...                 NaT
# 1       0107536000374040000022030012434300012521090109...                 NaT
# 2       0107536000374040000022030012434300012521091013...                 NaT
# 3       0107536000374040000022030012434300012521091317...                 NaT
# 4       0107536000374040000022030012434300012521091317...                 NaT
# ...                                                   ...                 ...
# 543071                                                NaN 2024-04-11 16:36:35
# 543072                                                NaN 2024-04-11 17:02:43
# 543073                                                NaN 2024-04-11 17:19:19
# 543074                                                    2024-04-11 17:21:51
# 543075                                                NaN 2024-04-11 17:55:38
#
#                         ref1 status  point promotion         actual_time  \
# 0       WI9FIRQJNZGK8Q15Z0M6  False    NaN       NaN                 NaT
# 1       TJCRE95Q3JB73MXDJ8U3  False    NaN       NaN                 NaT
# 2       CW2AEP6Q2EMW3S45KFSN  False    NaN       NaN                 NaT
# 3       H93RS1DFP8CWQIFAN2ED  False     18         0                 NaT
# 4       0QEZB1JQBB5EY5W0CRFU  False      3         0                 NaT
# ...                      ...    ...    ...       ...                 ...
# 543071                   NaN   True   4100       NaN 2024-04-11 16:36:35
# 543072                   NaN   True  12500       NaN 2024-04-11 17:02:43
# 543073                   NaN   True   4100       NaN 2024-04-11 17:19:19
# 543074                          NaN  10000         0 2024-04-11 17:21:51
# 543075                   NaN   True    520       NaN 2024-04-11 17:55:38
#
#        sale_code_name package_sub  action subscription sub_id
# 0                 NaN         NaN     NaN          NaN    NaN
# 1                 NaN         NaN     NaN          NaN    NaN
# 2                 NaN         NaN     NaN          NaN    NaN
# 3                 NaN         NaN     NaN          NaN    NaN
# 4                 NaN         NaN     NaN          NaN    NaN
# ...               ...         ...     ...          ...    ...
# 543071                        NaN     NaN         Free    NaN
# 543072                        NaN     NaN         Free    NaN
# 543073                        NaN     NaN         Free    NaN
# 543074                        NaN  add_on          NaN    NaN
# 543075                        NaN     NaN         Free    NaN
#
# [543076 rows x 17 columns]

# %%
# นำข้อมูลจากคอลัมน์ 'actual_time' มาใส่แทนค่าว่างในคอลัมน์ 'datetime'
df_pay['datetime'].fillna(df_pay['actual_time'], inplace=True)

# นำข้อมูลจากคอลัมน์ 'datetime' มาใส่แทนค่าว่างในคอลัมน์ 'actual_time'
df_pay['actual_time'].fillna(df_pay['datetime'], inplace=True)

# แสดง DataFrame หลังจากการแทนค่า
df_pay
# Out:
#                              _id                            user_id  \
# 0       612e3e206bcbfac605a1c8aa  U8530610030c64cc1843fd0f95b5f2758
# 1       612ee88ce827b44913887b68  U1d068ce57105d8463132691e9c2a4c3e
# 2       613afeffbd6b51f5666f4dca  U3bdae9df091601f970a61ff8e5d5a72a
# 3       613f26db233bb14db8f57c5e  U10e1ae0a6e2e2102ce01e8b3aca82433
# 4       613f2949233bb14db8f57c60  U3bdae9df091601f970a61ff8e5d5a72a
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price                                             qrcode  \
# 0             150    50  00020101021230820016A0000006770101120115010753...
# 1             150    50  00020101021230820016A0000006770101120115010753...
# 2             150    50  00020101021230820016A0000006770101120115010753...
# 3         credits     9  00020101021230820016A0000006770101120115010753...
# 4         credits     1  00020101021230820016A0000006770101120115010753...
# ...           ...   ...                                                ...
# 543071    pack_99    99                                                NaN
# 543072   pack_299   199                                                NaN
# 543073    pack_99    99                                                NaN
# 543074          1   500
# 543075     credit    13                                                NaN
#
#                                             transactionid            datetime  \
# 0       0107536000374040000022030012434300012521083121...                 NaT
# 1       0107536000374040000022030012434300012521090109...                 NaT
# 2       0107536000374040000022030012434300012521091013...                 NaT
# 3       0107536000374040000022030012434300012521091317...                 NaT
# 4       0107536000374040000022030012434300012521091317...                 NaT
# ...                                                   ...                 ...
# 543071                                                NaN 2024-04-11 16:36:35
# 543072                                                NaN 2024-04-11 17:02:43
# 543073                                                NaN 2024-04-11 17:19:19
# 543074                                                    2024-04-11 17:21:51
# 543075                                                NaN 2024-04-11 17:55:38
#
#                         ref1 status  point promotion         actual_time  \
# 0       WI9FIRQJNZGK8Q15Z0M6  False    NaN       NaN                 NaT
# 1       TJCRE95Q3JB73MXDJ8U3  False    NaN       NaN                 NaT
# 2       CW2AEP6Q2EMW3S45KFSN  False    NaN       NaN                 NaT
# 3       H93RS1DFP8CWQIFAN2ED  False     18         0                 NaT
# 4       0QEZB1JQBB5EY5W0CRFU  False      3         0                 NaT
# ...                      ...    ...    ...       ...                 ...
# 543071                   NaN   True   4100       NaN 2024-04-11 16:36:35
# 543072                   NaN   True  12500       NaN 2024-04-11 17:02:43
# 543073                   NaN   True   4100       NaN 2024-04-11 17:19:19
# 543074                          NaN  10000         0 2024-04-11 17:21:51
# 543075                   NaN   True    520       NaN 2024-04-11 17:55:38
#
#        sale_code_name package_sub  action subscription sub_id
# 0                 NaN         NaN     NaN          NaN    NaN
# 1                 NaN         NaN     NaN          NaN    NaN
# 2                 NaN         NaN     NaN          NaN    NaN
# 3                 NaN         NaN     NaN          NaN    NaN
# 4                 NaN         NaN     NaN          NaN    NaN
# ...               ...         ...     ...          ...    ...
# 543071                        NaN     NaN         Free    NaN
# 543072                        NaN     NaN         Free    NaN
# 543073                        NaN     NaN         Free    NaN
# 543074                        NaN  add_on          NaN    NaN
# 543075                        NaN     NaN         Free    NaN
#
# [543076 rows x 17 columns]

# %%
df_pay2 = df_pay[df_pay['datetime'].dt.year >= 2024]

# กรองเอาเฉพาะตั้งเเต่เดือน 2 ปี 2024
df_pay2 = df_pay2[df_pay2['datetime'].dt.month >= 2]

df_pay2
# Out:
#                              _id                            user_id  \
# 535350  65ba8072ef414a50d242262a  Ue9959631ee4a073ca289c2c3e688a1bf
# 535351  65ba81192b78849873dc9b45  U6ce3d760222037a681bfbdd402a602c2
# 535352  65ba81388edc5ec335664183       Hww3kMohYJeeKMSwiZZQvkK1A4E2
# 535353  65ba81aeef414a50d242262c  U902a1c53e716b3e36557f62df8ffa321
# 535354  65ba832a2b78849873dc9b47       RW18HHlRJ1MuRToRJsY5yzsKZoT2
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price qrcode transactionid            datetime ref1 status  \
# 535350   pack_299   199    NaN           NaN 2024-02-01 00:16:34  NaN   True
# 535351   pack_299   199    NaN           NaN 2024-02-01 00:19:21  NaN   True
# 535352     credit    43    NaN           NaN 2024-02-01 00:19:52  NaN   True
# 535353   pack_299   200    NaN           NaN 2024-02-01 00:21:50  NaN   True
# 535354     credit   100    NaN           NaN 2024-02-01 00:28:10  NaN   True
# ...           ...   ...    ...           ...                 ...  ...    ...
# 543071    pack_99    99    NaN           NaN 2024-04-11 16:36:35  NaN   True
# 543072   pack_299   199    NaN           NaN 2024-04-11 17:02:43  NaN   True
# 543073    pack_99    99    NaN           NaN 2024-04-11 17:19:19  NaN   True
# 543074          1   500                      2024-04-11 17:21:51         NaN
# 543075     credit    13    NaN           NaN 2024-04-11 17:55:38  NaN   True
#
#         point promotion         actual_time sale_code_name package_sub  \
# 535350  12500       NaN 2024-02-01 00:16:34                        NaN
# 535351  12500       NaN 2024-02-01 00:19:21                        NaN
# 535352   1720       NaN 2024-02-01 00:19:52                        NaN
# 535353  12500       NaN 2024-02-01 00:21:50                        NaN
# 535354   4000       NaN 2024-02-01 00:28:10                        NaN
# ...       ...       ...                 ...            ...         ...
# 543071   4100       NaN 2024-04-11 16:36:35                        NaN
# 543072  12500       NaN 2024-04-11 17:02:43                        NaN
# 543073   4100       NaN 2024-04-11 17:19:19                        NaN
# 543074  10000         0 2024-04-11 17:21:51                        NaN
# 543075    520       NaN 2024-04-11 17:55:38                        NaN
#
#         action subscription sub_id
# 535350     NaN         Free    NaN
# 535351     NaN         Free    NaN
# 535352     NaN         Free    NaN
# 535353     NaN         Free    NaN
# 535354     NaN         Free    NaN
# ...        ...          ...    ...
# 543071     NaN         Free    NaN
# 543072     NaN         Free    NaN
# 543073     NaN         Free    NaN
# 543074  add_on          NaN    NaN
# 543075     NaN         Free    NaN
#
# [7726 rows x 17 columns]

# %%
df_pay2 = df_pay[df_pay['actual_time'].dt.year >= 2024]

# กรองเอาเฉพาะตั้งเเต่เดือน 2 ปี 2024
df_pay2 = df_pay2[df_pay2['actual_time'].dt.month >= 2]

df_pay2
# Out:
#                              _id                            user_id  \
# 535350  65ba8072ef414a50d242262a  Ue9959631ee4a073ca289c2c3e688a1bf
# 535351  65ba81192b78849873dc9b45  U6ce3d760222037a681bfbdd402a602c2
# 535352  65ba81388edc5ec335664183       Hww3kMohYJeeKMSwiZZQvkK1A4E2
# 535353  65ba81aeef414a50d242262c  U902a1c53e716b3e36557f62df8ffa321
# 535354  65ba832a2b78849873dc9b47       RW18HHlRJ1MuRToRJsY5yzsKZoT2
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price qrcode transactionid            datetime ref1 status  \
# 535350   pack_299   199    NaN           NaN 2024-02-01 00:16:34  NaN   True
# 535351   pack_299   199    NaN           NaN 2024-02-01 00:19:21  NaN   True
# 535352     credit    43    NaN           NaN 2024-02-01 00:19:52  NaN   True
# 535353   pack_299   200    NaN           NaN 2024-02-01 00:21:50  NaN   True
# 535354     credit   100    NaN           NaN 2024-02-01 00:28:10  NaN   True
# ...           ...   ...    ...           ...                 ...  ...    ...
# 543071    pack_99    99    NaN           NaN 2024-04-11 16:36:35  NaN   True
# 543072   pack_299   199    NaN           NaN 2024-04-11 17:02:43  NaN   True
# 543073    pack_99    99    NaN           NaN 2024-04-11 17:19:19  NaN   True
# 543074          1   500                      2024-04-11 17:21:51         NaN
# 543075     credit    13    NaN           NaN 2024-04-11 17:55:38  NaN   True
#
#         point promotion         actual_time sale_code_name package_sub  \
# 535350  12500       NaN 2024-02-01 00:16:34                        NaN
# 535351  12500       NaN 2024-02-01 00:19:21                        NaN
# 535352   1720       NaN 2024-02-01 00:19:52                        NaN
# 535353  12500       NaN 2024-02-01 00:21:50                        NaN
# 535354   4000       NaN 2024-02-01 00:28:10                        NaN
# ...       ...       ...                 ...            ...         ...
# 543071   4100       NaN 2024-04-11 16:36:35                        NaN
# 543072  12500       NaN 2024-04-11 17:02:43                        NaN
# 543073   4100       NaN 2024-04-11 17:19:19                        NaN
# 543074  10000         0 2024-04-11 17:21:51                        NaN
# 543075    520       NaN 2024-04-11 17:55:38                        NaN
#
#         action subscription sub_id
# 535350     NaN         Free    NaN
# 535351     NaN         Free    NaN
# 535352     NaN         Free    NaN
# 535353     NaN         Free    NaN
# 535354     NaN         Free    NaN
# ...        ...          ...    ...
# 543071     NaN         Free    NaN
# 543072     NaN         Free    NaN
# 543073     NaN         Free    NaN
# 543074  add_on          NaN    NaN
# 543075     NaN         Free    NaN
#
# [7726 rows x 17 columns]

# %%
#6-11= morning, 12-17 = afternoon, 18-23 = evening, 0-5 = night
def categorize_data(datetime_value):

  hour = datetime_value.hour
  time_range = 'Morning' if 6 <= hour <= 11 else (
        'Afternoon' if 12 <= hour <= 17 else (
            'Evening' if 18 <= hour <= 23 else 'Night')
    )

  return time_range

# %%
df_pay2['time_range'] = df_pay2['datetime'].apply(categorize_data)
df_pay2
# Out:
#                              _id                            user_id  \
# 535350  65ba8072ef414a50d242262a  Ue9959631ee4a073ca289c2c3e688a1bf
# 535351  65ba81192b78849873dc9b45  U6ce3d760222037a681bfbdd402a602c2
# 535352  65ba81388edc5ec335664183       Hww3kMohYJeeKMSwiZZQvkK1A4E2
# 535353  65ba81aeef414a50d242262c  U902a1c53e716b3e36557f62df8ffa321
# 535354  65ba832a2b78849873dc9b47       RW18HHlRJ1MuRToRJsY5yzsKZoT2
# ...                          ...                                ...
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543074  6617b9c0aac092e235a2127a       Jh23z6LUlpVEC8MNoFCznnRGyrB2
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price qrcode transactionid            datetime ref1 status  \
# 535350   pack_299   199    NaN           NaN 2024-02-01 00:16:34  NaN   True
# 535351   pack_299   199    NaN           NaN 2024-02-01 00:19:21  NaN   True
# 535352     credit    43    NaN           NaN 2024-02-01 00:19:52  NaN   True
# 535353   pack_299   200    NaN           NaN 2024-02-01 00:21:50  NaN   True
# 535354     credit   100    NaN           NaN 2024-02-01 00:28:10  NaN   True
# ...           ...   ...    ...           ...                 ...  ...    ...
# 543071    pack_99    99    NaN           NaN 2024-04-11 16:36:35  NaN   True
# 543072   pack_299   199    NaN           NaN 2024-04-11 17:02:43  NaN   True
# 543073    pack_99    99    NaN           NaN 2024-04-11 17:19:19  NaN   True
# 543074          1   500                      2024-04-11 17:21:51         NaN
# 543075     credit    13    NaN           NaN 2024-04-11 17:55:38  NaN   True
#
#         point promotion         actual_time sale_code_name package_sub  \
# 535350  12500       NaN 2024-02-01 00:16:34                        NaN
# 535351  12500       NaN 2024-02-01 00:19:21                        NaN
# 535352   1720       NaN 2024-02-01 00:19:52                        NaN
# 535353  12500       NaN 2024-02-01 00:21:50                        NaN
# 535354   4000       NaN 2024-02-01 00:28:10                        NaN
# ...       ...       ...                 ...            ...         ...
# 543071   4100       NaN 2024-04-11 16:36:35                        NaN
# 543072  12500       NaN 2024-04-11 17:02:43                        NaN
# 543073   4100       NaN 2024-04-11 17:19:19                        NaN
# 543074  10000         0 2024-04-11 17:21:51                        NaN
# 543075    520       NaN 2024-04-11 17:55:38                        NaN
#
#         action subscription sub_id time_range
# 535350     NaN         Free    NaN      Night
# 535351     NaN         Free    NaN      Night
# 535352     NaN         Free    NaN      Night
# 535353     NaN         Free    NaN      Night
# 535354     NaN         Free    NaN      Night
# ...        ...          ...    ...        ...
# 543071     NaN         Free    NaN  Afternoon
# 543072     NaN         Free    NaN  Afternoon
# 543073     NaN         Free    NaN  Afternoon
# 543074  add_on          NaN    NaN  Afternoon
# 543075     NaN         Free    NaN  Afternoon
#
# [7726 rows x 18 columns]

# %%
df_pay2['hour'] = pd.to_datetime(df_pay2['datetime']).dt.hour
df_pay2['day_of_week'] = pd.to_datetime(df_pay2['datetime']).dt.day_name()

# %%
df_pay_true = df_pay2[df_pay2['status'] == True]
df_pay_true
# Out:
#                              _id                            user_id  \
# 535350  65ba8072ef414a50d242262a  Ue9959631ee4a073ca289c2c3e688a1bf
# 535351  65ba81192b78849873dc9b45  U6ce3d760222037a681bfbdd402a602c2
# 535352  65ba81388edc5ec335664183       Hww3kMohYJeeKMSwiZZQvkK1A4E2
# 535353  65ba81aeef414a50d242262c  U902a1c53e716b3e36557f62df8ffa321
# 535354  65ba832a2b78849873dc9b47       RW18HHlRJ1MuRToRJsY5yzsKZoT2
# ...                          ...                                ...
# 543070  6617a9463f38f8578a814cce       somdP4tVafXdi3MZJM11ZSHJDO82
# 543071  6617af23aac092e235a21277       A9NaXDdchAgbw8swpxHdrbchicw1
# 543072  6617b543aac092e235a21278  U553b8f26941230a2181321976f3c79a9
# 543073  6617b9273f38f8578a814cd2  U51916e72f52c24c4ac7657dcc8b1c11e
# 543075  6617c1aa3f38f8578a814cd4       ltpGncqnWqMDJZsjTPjShuL683x1
#
#        package_id price qrcode transactionid            datetime ref1 status  \
# 535350   pack_299   199    NaN           NaN 2024-02-01 00:16:34  NaN   True
# 535351   pack_299   199    NaN           NaN 2024-02-01 00:19:21  NaN   True
# 535352     credit    43    NaN           NaN 2024-02-01 00:19:52  NaN   True
# 535353   pack_299   200    NaN           NaN 2024-02-01 00:21:50  NaN   True
# 535354     credit   100    NaN           NaN 2024-02-01 00:28:10  NaN   True
# ...           ...   ...    ...           ...                 ...  ...    ...
# 543070   pack_750   400    NaN           NaN 2024-04-11 16:11:34  NaN   True
# 543071    pack_99    99    NaN           NaN 2024-04-11 16:36:35  NaN   True
# 543072   pack_299   199    NaN           NaN 2024-04-11 17:02:43  NaN   True
# 543073    pack_99    99    NaN           NaN 2024-04-11 17:19:19  NaN   True
# 543075     credit    13    NaN           NaN 2024-04-11 17:55:38  NaN   True
#
#         point promotion         actual_time sale_code_name package_sub action  \
# 535350  12500       NaN 2024-02-01 00:16:34                        NaN    NaN
# 535351  12500       NaN 2024-02-01 00:19:21                        NaN    NaN
# 535352   1720       NaN 2024-02-01 00:19:52                        NaN    NaN
# 535353  12500       NaN 2024-02-01 00:21:50                        NaN    NaN
# 535354   4000       NaN 2024-02-01 00:28:10                        NaN    NaN
# ...       ...       ...                 ...            ...         ...    ...
# 543070  30000       NaN 2024-04-11 16:11:34                        NaN    NaN
# 543071   4100       NaN 2024-04-11 16:36:35                        NaN    NaN
# 543072  12500       NaN 2024-04-11 17:02:43                        NaN    NaN
# 543073   4100       NaN 2024-04-11 17:19:19                        NaN    NaN
# 543075    520       NaN 2024-04-11 17:55:38                        NaN    NaN
#
#        subscription sub_id time_range  hour day_of_week
# 535350         Free    NaN      Night     0    Thursday
# 535351         Free    NaN      Night     0    Thursday
# 535352         Free    NaN      Night     0    Thursday
# 535353         Free    NaN      Night     0    Thursday
# 535354         Free    NaN      Night     0    Thursday
# ...             ...    ...        ...   ...         ...
# 543070         Free    NaN  Afternoon    16    Thursday
# 543071         Free    NaN  Afternoon    16    Thursday
# 543072         Free    NaN  Afternoon    17    Thursday
# 543073         Free    NaN  Afternoon    17    Thursday
# 543075         Free    NaN  Afternoon    17    Thursday
#
# [7207 rows x 20 columns]

# %%
df_pay_false = df_pay2[df_pay2['status'] == False]
df_pay_false
# Out:
#                              _id                            user_id  \
# 535362  65baeb01a50a5238cd5fb1d3       Buxv8DsEFBYo6iwcLhzSm49Ci7A3
# 535367  65bb0677c2dc6cc4b3b5a313  Ue00375e930539d4cbded50d46ee91733
# 535383  65bb23632b78849873dc9b5c       kYKTrkM2Z9P8OaBw3T6yua9eU0f2
# 535426  65bb8c0c01cf854582846cdc       Kc6uvsAfjNfdg6CyZQF65DkDdmH3
# 535433  65bb99bd567381194454ce04  U93071731ad216a1b7f6a7f0750a0656d
# ...                          ...                                ...
# 542687  660e309a923e21bccbc25a72       gKhn4GNjIOfEAF2N7goNcPRqPG63
# 542779  660fbf093f38f8578a814b14       GMdklXnjXQRsW9ksMgE0kEOGLc73
# 542792  66101973aac092e235a210bb       VawXoWtiauTgUjhcI2hucFo9DYG3
# 542842  6611b55eaac092e235a210e6       4vsqOLRjn5S5uQww02bNxFzBHJa2
# 542920  661412da3f38f8578a814be9       9emP6ETkXEZ3351DY9j6O5mwxu52
#
#        package_id price                                             qrcode  \
# 535362     credit     4  00020101021230720016A0000006770101120115010556...
# 535367     credit     5  00020101021230720016A0000006770101120115010556...
# 535383     credit     5  00020101021230720016A0000006770101120115010556...
# 535426     credit     9  00020101021230720016A0000006770101120115010556...
# 535433     credit     4  00020101021230720016A0000006770101120115010556...
# ...           ...   ...                                                ...
# 542687     credit     5  00020101021230720016A0000006770101120115010556...
# 542779     credit     3  00020101021230720016A0000006770101120115010556...
# 542792     credit     3  00020101021230720016A0000006770101120115010556...
# 542842     credit     1  00020101021230720016A0000006770101120115010556...
# 542920     credit     8  00020101021230720016A0000006770101120115010556...
#
#                                    transactionid            datetime  \
# 535362  010556021375502TTS50JSRFHG2M04N2H8SIBNQR 2024-02-01 00:51:13
# 535367  010556021375502TTSX6F9JC6MBMOK3AY2QIBNQR 2024-02-01 02:48:23
# 535383  010556021375502TTSFYF3YZAN06VG5XUHKIBNQR 2024-02-01 04:51:47
# 535426  010556021375502TTSFTEJ1PNTT5LGT3LQUIBNQR 2024-02-01 12:18:20
# 535433  010556021375502TTSP5JUOU6N0APFXKZLIIBNQR 2024-02-01 13:16:45
# ...                                          ...                 ...
# 542687  010556021375502TTSFJCQTE19WVBYZYO6RIBNQR 2024-04-04 04:46:18
# 542779  010556021375502TTSN4M4472EIPTSWP426IBNQR 2024-04-05 09:06:17
# 542792  010556021375502TTSVR6RYGURNFZTLXUK0IBNQR 2024-04-05 15:32:03
# 542842  010556021375502TTSVVN01QFTIMZ7F8XREIBNQR 2024-04-06 20:49:34
# 542920  010556021375502TTSGCP5S6EOYD5FN6ADSIBNQR 2024-04-08 15:52:58
#
#                         ref1 status point promotion         actual_time  \
# 535362  TTS50JSRFHG2M04N2H8S  False   150         0 2024-02-01 00:51:13
# 535367  TTSX6F9JC6MBMOK3AY2Q  False   200         0 2024-02-01 02:48:23
# 535383  TTSFYF3YZAN06VG5XUHK  False   199         0 2024-02-01 04:51:47
# 535426  TTSFTEJ1PNTT5LGT3LQU  False   351         0 2024-02-01 12:18:20
# 535433  TTSP5JUOU6N0APFXKZLI  False   140         0 2024-02-01 13:16:45
# ...                      ...    ...   ...       ...                 ...
# 542687  TTSFJCQTE19WVBYZYO6R  False   195         0 2024-04-04 04:46:18
# 542779  TTSN4M4472EIPTSWP426  False   100         0 2024-04-05 09:06:17
# 542792  TTSVR6RYGURNFZTLXUK0  False   132         0 2024-04-05 15:32:03
# 542842  TTSVVN01QFTIMZ7F8XRE  False    30         0 2024-04-06 20:49:34
# 542920  TTSGCP5S6EOYD5FN6ADS  False   300         0 2024-04-08 15:52:58
#
#        sale_code_name package_sub action subscription sub_id time_range  hour  \
# 535362            NaN         NaN    NaN          NaN    NaN      Night     0
# 535367            NaN         NaN    NaN          NaN    NaN      Night     2
# 535383            NaN         NaN    NaN          NaN    NaN      Night     4
# 535426            NaN         NaN    NaN          NaN    NaN  Afternoon    12
# 535433            NaN         NaN    NaN          NaN    NaN  Afternoon    13
# ...               ...         ...    ...          ...    ...        ...   ...
# 542687            NaN         NaN    NaN          NaN    NaN      Night     4
# 542779            NaN         NaN    NaN          NaN    NaN    Morning     9
# 542792            NaN         NaN    NaN          NaN    NaN  Afternoon    15
# 542842            NaN         NaN    NaN          NaN    NaN    Evening    20
# 542920            NaN         NaN    NaN          NaN    NaN  Afternoon    15
#
#        day_of_week
# 535362    Thursday
# 535367    Thursday
# 535383    Thursday
# 535426    Thursday
# 535433    Thursday
# ...            ...
# 542687    Thursday
# 542779      Friday
# 542792      Friday
# 542842    Saturday
# 542920      Monday
#
# [256 rows x 20 columns]

# %%
# ดึงเฉพาะหัวข้อ (column)
headers = df_pay_true.columns

# พิมพ์หัวข้อ
print(headers)
# Out:
# Index(['_id', 'user_id', 'package_id', 'price', 'qrcode', 'transactionid',
#        'datetime', 'ref1', 'status', 'point', 'promotion', 'actual_time',
#        'sale_code_name', 'package_sub', 'action', 'subscription', 'sub_id',
#        'time_range', 'hour', 'day_of_week'],
#       dtype='object')

# %%
color_time = {
    'Morning': 'hsl(60, 70%, 70%)',  # เหลือง
    'Afternoon': 'hsl(30, 70%, 70%)',  # ส้ม
    'Evening': 'hsl(240, 70%, 70%)',  # ฟ้า
    'Night': 'hsl(270, 70%, 70%)',  # ม่วง

}

# %% [markdown]
# #ช่วงเวลาการใช้ของคนทั้งหมด

# %%
import plotly.express as px

# รวมและเรียงข้อมูลตามช่วงเวลา
df_sorted = df_pay2['time_range'].value_counts().sort_values(ascending=False).reset_index()
df_sorted.columns = ['Time Range', 'Count']

# สร้างข้อความที่ต้องการแสดงในแต่ละแท่งกราฟ
text_data = [f"{count}" for count in df_sorted['Count']]

# สร้างกราฟแท่งด้วย Plotly Express
fig = px.bar(df_sorted,
             x='Time Range',  # ให้แกน x เป็นช่วงเวลา
             y='Count',  # ให้แกน y เป็นจำนวนการเกิดขึ้น
             labels={'Time Range': 'Time Range', 'Count': 'Count'},  # กำหนด label ให้แกน x และ y
             title='Count of Entries by Time Range',
             text=text_data,  # เพิ่มข้อความ
             color='Time Range',  # ใช้ช่วงเวลาเป็นสี
             color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
             )

# เพิ่ม label ให้กับแกน x และ y
fig.update_xaxes(title_text='Time Range')
fig.update_yaxes(title_text='Count')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ddc90c9f-7d62-434c-ac2f-08402309187d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddc90c9f-7d62-434c-ac2f-08402309187d")) {                    Plotly.newPlot(                        "ddc90c9f-7d62-434c-ac2f-08402309187d",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"text":["2916"],"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[2916],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"text":["2087"],"textposition":"auto","x":["Evening"],"xaxis":"x","y":[2087],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"text":["1950"],"textposition":"auto","x":["Morning"],"xaxis":"x","y":[1950],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"text":["773"],"textposition":"auto","x":["Night"],"xaxis":"x","y":[773],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# #ช่วงเวลาการใช้ของคนจ่ายเงิน

# %%
import plotly.express as px

# รวมและเรียงข้อมูลตามช่วงเวลา
df_sorted = df_pay_true['time_range'].value_counts().sort_values(ascending=False).reset_index()
df_sorted.columns = ['Time Range', 'Count']

# สร้างข้อความที่ต้องการแสดงในแต่ละแท่งกราฟ
text_data = [f"{count}" for count in df_sorted['Count']]

# สร้างกราฟแท่งด้วย Plotly Express
fig = px.bar(df_sorted,
             x='Time Range',  # ให้แกน x เป็นช่วงเวลา
             y='Count',  # ให้แกน y เป็นจำนวนการเกิดขึ้น
             labels={'Time Range': 'Time Range', 'Count': 'Count'},  # กำหนด label ให้แกน x และ y
             title='Count of Entries by Time Range',
             text=text_data,  # เพิ่มข้อความ
             color='Time Range',  # ใช้ช่วงเวลาเป็นสี
             color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
             )

# เพิ่ม label ให้กับแกน x และ y
fig.update_xaxes(title_text='Time Range')
fig.update_yaxes(title_text='Count')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bcb8a2d3-ac9c-4de1-888c-dc5565030110" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcb8a2d3-ac9c-4de1-888c-dc5565030110")) {                    Plotly.newPlot(                        "bcb8a2d3-ac9c-4de1-888c-dc5565030110",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"text":["2758"],"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[2758],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"text":["1986"],"textposition":"auto","x":["Evening"],"xaxis":"x","y":[1986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"text":["1748"],"textposition":"auto","x":["Morning"],"xaxis":"x","y":[1748],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"text":["715"],"textposition":"auto","x":["Night"],"xaxis":"x","y":[715],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# #ช่วงเวลาการใช้ของคนไม่จ่ายเงิน

# %%
import plotly.express as px

# รวมและเรียงข้อมูลตามช่วงเวลา
df_sorted = df_pay_false['time_range'].value_counts().sort_values(ascending=False).reset_index()
df_sorted.columns = ['Time Range', 'Count']

# สร้างข้อความที่ต้องการแสดงในแต่ละแท่งกราฟ
text_data = [f"{count}" for count in df_sorted['Count']]

# สร้างกราฟแท่งด้วย Plotly Express
fig = px.bar(df_sorted,
             x='Time Range',  # ให้แกน x เป็นช่วงเวลา
             y='Count',  # ให้แกน y เป็นจำนวนการเกิดขึ้น
             labels={'Time Range': 'Time Range', 'Count': 'Count'},  # กำหนด label ให้แกน x และ y
             title='Count of Entries by Time Range',
             text=text_data,  # เพิ่มข้อความ
             color='Time Range',  # ใช้ช่วงเวลาเป็นสี
             color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
             )

# เพิ่ม label ให้กับแกน x และ y
fig.update_xaxes(title_text='Time Range')
fig.update_yaxes(title_text='Count')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a0ec06b7-cdd7-4292-9a4e-785d3c69ede7" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0ec06b7-cdd7-4292-9a4e-785d3c69ede7")) {                    Plotly.newPlot(                        "a0ec06b7-cdd7-4292-9a4e-785d3c69ede7",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"text":["101"],"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[101],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"text":["82"],"textposition":"auto","x":["Morning"],"xaxis":"x","y":[82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"text":["48"],"textposition":"auto","x":["Night"],"xaxis":"x","y":[48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"text":["25"],"textposition":"auto","x":["Evening"],"xaxis":"x","y":[25],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colors ...

# %%
color_map = {
    'Monday': 'hsl(60, 70%, 70%)',  # เหลือง
    'Tuesday': 'hsl(330, 70%, 70%)',  # ชมพู
    'Wednesday': 'hsl(120, 70%, 70%)',  # เขียว
    'Thursday': 'hsl(30, 70%, 70%)',  # ส้ม
    'Friday': 'hsl(240, 70%, 70%)',  # ฟ้า
    'Saturday': 'hsl(270, 70%, 70%)',  # ม่วง
    'Sunday': 'hsl(0, 70%, 70%)'  # แดง
}

# %%
import plotly.express as px

# รวมและเรียงข้อมูลตามช่วงเวลา
df_sorted = df_pay_true['time_range'].value_counts().sort_values(ascending=False).reset_index()
df_sorted.columns = ['Time Range', 'Count']

# สร้างข้อความที่ต้องการแสดงในแต่ละแท่งกราฟ
text_data = [f"{count}" for count in df_sorted['Count']]

# สร้างกราฟแท่งด้วย Plotly Express
fig = px.bar(df_sorted,
             x='Time Range',  # ให้แกน x เป็นช่วงเวลา
             y='Count',  # ให้แกน y เป็นจำนวนการเกิดขึ้น
             labels={'Time Range': 'Time Range', 'Count': 'Count'},  # กำหนด label ให้แกน x และ y
             title='Count of Entries by Time Range',
             text=text_data,  # เพิ่มข้อความ
             color='Time Range',  # ใช้ช่วงเวลาเป็นสี
             color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
             )

# เพิ่ม label ให้กับแกน x และ y
fig.update_xaxes(title_text='Time Range')
fig.update_yaxes(title_text='Count')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e3be1035-51bb-4804-9b66-ee053751f8b2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3be1035-51bb-4804-9b66-ee053751f8b2")) {                    Plotly.newPlot(                        "e3be1035-51bb-4804-9b66-ee053751f8b2",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"text":["2758"],"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[2758],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"text":["1986"],"textposition":"auto","x":["Evening"],"xaxis":"x","y":[1986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"text":["1748"],"textposition":"auto","x":["Morning"],"xaxis":"x","y":[1748],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"text":["715"],"textposition":"auto","x":["Night"],"xaxis":"x","y":[715],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks" ...

# %%
color_map
# Out:
# {'Monday': 'hsl(60, 70%, 70%)',
#  'Tuesday': 'hsl(330, 70%, 70%)',
#  'Wednesday': 'hsl(120, 70%, 70%)',
#  'Thursday': 'hsl(30, 70%, 70%)',
#  'Friday': 'hsl(240, 70%, 70%)',
#  'Saturday': 'hsl(270, 70%, 70%)',
#  'Sunday': 'hsl(0, 70%, 70%)'}

# %%
import plotly.express as px
import pandas as pd

# กำหนดช่วงราคาและชื่อของแต่ละช่วง
bin_edges = [0, 101, 201, 301, 401, 501, 1001, 2001, 3001, 4001, 5001, 10001, float('inf')]
bin_labels = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-1000', '1001-2000', '2001-3000', '3001-4000', '4001-5000', '5001-10000', '10000+']

# แปลงชนิดข้อมูลในคอลัมน์ 'price_bins' เป็นตัวเลข
df_pay_true['price'] = df_pay_true['price'].astype(float)

# ใช้ pd.cut() เพื่อแบ่งข้อมูลในช่วงตามที่กำหนด
df_pay_true['price_bins'] = pd.cut(df_pay_true['price'], bins=bin_edges, labels=bin_labels)

# สร้างกราฟ histogram ด้วย Plotly Express
fig = px.histogram(df_pay_true, x='price_bins', title='Histogram of Price (Frequency)', labels={'price_bins': 'Price Range', 'count': 'Frequency'})

# เรียงลำดับข้อมูลในแนวแกน x จากมากไปน้อย
fig.update_xaxes(categoryorder='total descending')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <ipython-input-29-a5687baf6a03>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-29-a5687baf6a03>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e0d0ddc-8b34-421b-b11b-e6f4ad8c0ad2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e0d0ddc-8b34-421b-b11b-e6f4ad8c0ad2")) {                    Plotly.newPlot(                        "3e0d0ddc-8b34-421b-b11b-e6f4ad8c0ad2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price Range=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["101-200","101-200","0-100","101-200","0-100","101-200","101-200","101-200","101-200","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","501-1000","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","101-200","101-200","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","0-100","101-200","0-100","0-100","5001-10000","0-100","0-100","0-100","0-100","301-400","0-100","0-100","101-200","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","0-100","0-100","0-100","0-100","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","101-200","101-200","0-100","0-100","0-100","0-100","1001-2000","0-100","0-100","101-200","0-100","0-100","101-200","0-100","101-200","101-200","0-100","101-200","0-100","0-100","101-200","301-400","101-200","0-100","0-100","0-100","0-100","0-100","0-100","101-200","101-200","0-100","101-200","0-100","0-100","0-100","0-100","0-100","501-1000","101-200","0-100","101-200","101-200","0-100","0-100","501-1000","101-200","101-200","101-200","0-100","101-200","0-100","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","101-200","501-1000","0-100","101-200","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","101-200","0-100","0-100","501-1000","101-200","101-200","0-100","101-200","0-100","101-200","0-100","0-100","0-100","0-100","101-200","0-100","101-200","101-200","101-200","0-100","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","101-200","0-100","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","301-400","101-200","0-100","101-200","0-100","101-200","0-100","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","301-400","101-200","101-200","0-100","301-400","0-100","0-100","0-100","101-200","0-100","101-200","501-1000","101-200","0-100","0-100","0-100","101-200","0-100","101-200","101-200","101-200","0-100","101-200","101-200","0-100","0-100","0-100","0-100","301-400","0-100","0-100","0-100","101-200","0-100","301-400","0-100","101-200","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","501-1000","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","101-200","301-400","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-2 ...

# %%
bin_edges = [0, 101, 201, 301, 401, 501, 1001, 2001, 3001, 4001, 5001, 10001, float('inf')]
bin_labels = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-1000', '1001-2000', '2001-3000', '3001-4000', '4001-5000', '5001-10000', '10000+']
df_pay_true['price_bins'] = pd.cut(df_pay_true['price'], bins=bin_edges, labels=bin_labels)
fig = px.histogram(df_pay_true, x='price_bins', y='price', histfunc='sum', title='Histogram of Price (Sum)', labels={'price_bins': 'Price Range', 'price': 'Sum of Prices'})
# เรียงลำดับข้อมูลในแนวแกน x จากมากไปน้อย
fig.update_xaxes(categoryorder='total descending')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <ipython-input-30-2ecb2ac5f987>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0abceccd-c317-49ed-8249-373af8649c9c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0abceccd-c317-49ed-8249-373af8649c9c")) {                    Plotly.newPlot(                        "0abceccd-c317-49ed-8249-373af8649c9c",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Price Range=%{x}\u003cbr\u003esum of Sum of Prices=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["101-200","101-200","0-100","101-200","0-100","101-200","101-200","101-200","101-200","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","501-1000","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","101-200","101-200","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","0-100","101-200","0-100","0-100","5001-10000","0-100","0-100","0-100","0-100","301-400","0-100","0-100","101-200","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","0-100","0-100","0-100","0-100","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","101-200","101-200","0-100","0-100","0-100","0-100","1001-2000","0-100","0-100","101-200","0-100","0-100","101-200","0-100","101-200","101-200","0-100","101-200","0-100","0-100","101-200","301-400","101-200","0-100","0-100","0-100","0-100","0-100","0-100","101-200","101-200","0-100","101-200","0-100","0-100","0-100","0-100","0-100","501-1000","101-200","0-100","101-200","101-200","0-100","0-100","501-1000","101-200","101-200","101-200","0-100","101-200","0-100","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","101-200","501-1000","0-100","101-200","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","101-200","0-100","0-100","501-1000","101-200","101-200","0-100","101-200","0-100","101-200","0-100","0-100","0-100","0-100","101-200","0-100","101-200","101-200","101-200","0-100","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","501-1000","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","101-200","0-100","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","301-400","101-200","0-100","101-200","0-100","101-200","0-100","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100","101-200","101-200","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","301-400","101-200","101-200","0-100","301-400","0-100","0-100","0-100","101-200","0-100","101-200","501-1000","101-200","0-100","0-100","0-100","101-200","0-100","101-200","101-200","101-200","0-100","101-200","101-200","0-100","0-100","0-100","0-100","301-400","0-100","0-100","0-100","101-200","0-100","301-400","0-100","101-200","0-100","0-100","0-100","0-100","0-100","101-200","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","501-1000","0-100","0-100","101-200","0-100","101-200","0-100","0-100","0-100","101-200","301-400","0-100","0-100","0-100","0-100","101-200","0-100","0-100","0-100","0-100","0-100","0-100","0-100","0-100 ...

# %%
import pandas as pd
import plotly.express as px

# กำหนดช่วงราคา
price_ranges = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-1000', '1001-2000', '2001-3000', '3001-4000', '4001-5000', '5001-10000', '10000+']

# สร้างกราฟสำหรับแต่ละช่วงราคา
for price_range in price_ranges:
  # กรองข้อมูลเฉพาะข้อมูลในช่วงราคา
  if price_range == '10000+':
    df_price_range = df_pay_true[df_pay_true['price'] >= 10000]
  else:
    price_range_min, price_range_max = map(int, price_range.split('-'))
    df_price_range = df_pay_true[(df_pay_true['price'] >= price_range_min) & (df_pay_true['price'] <= price_range_max)]

  # เรียงข้อมูลจากมากไปน้อย
  df_sorted = df_price_range['day_of_week'].value_counts().sort_values(ascending=False)

  # สร้าง DataFrame จาก Series
  df_bar_data = pd.DataFrame({'day_of_week': df_sorted.index, 'count': df_sorted.values})

  # สร้างกราฟแท่งด้วย Plotly Express
  fig = px.bar(df_bar_data,
                x='day_of_week',  # Set day_of_week as x-axis
                y='count',        # Set count as y-axis
                labels={'day_of_week': 'Day of Week', 'count': 'Count'},  # Set labels for axes
                title=f'Count of Entries by day_of_week (Price Range {price_range})',
                color='day_of_week',  # Use day_of_week for color differentiation
                color_discrete_map=color_map  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
              )

  # เพิ่ม label ให้กับแกน x และ y
  fig.update_xaxes(title_text='Day of Week')
  fig.update_yaxes(title_text='Count')

  # กำหนดขนาดของกราฟ
  fig.update_layout(width=800, height=600)

  # เพิ่มตัวเลขกำกับในกราฟแต่ละแท่ง
  for bar in fig.data:
    for i, j in enumerate(bar.y):
        text = f'{j}'
        fig.add_annotation(
            x=bar.x[i],
            y=j,
            text=text,
            textangle=0,
            showarrow=False,
            font_size=12,
        )

  # แสดงกราฟ
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="78563ce7-0082-44b5-860f-fdca00dda2eb" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78563ce7-0082-44b5-860f-fdca00dda2eb")) {                    Plotly.newPlot(                        "78563ce7-0082-44b5-860f-fdca00dda2eb",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[765],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[745],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[703],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[694],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[514],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[486],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7076c686-2db3-4d30-8ac0-5076bc081942" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7076c686-2db3-4d30-8ac0-5076bc081942")) {                    Plotly.newPlot(                        "7076c686-2db3-4d30-8ac0-5076bc081942",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[306],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[289],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[277],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[274],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[242],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[217],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[181],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="254d78e4-c20b-4648-bd55-630372e18a23" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("254d78e4-c20b-4648-bd55-630372e18a23")) {                    Plotly.newPlot(                        "254d78e4-c20b-4648-bd55-630372e18a23",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d563eada-95a1-44ce-9d85-157250085275" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d563eada-95a1-44ce-9d85-157250085275")) {                    Plotly.newPlot(                        "d563eada-95a1-44ce-9d85-157250085275",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[126],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[108],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[99],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[86],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[57],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5dacdef6-eb65-4e70-881f-d67d7fe8acfd" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dacdef6-eb65-4e70-881f-d67d7fe8acfd")) {                    Plotly.newPlot(                        "5dacdef6-eb65-4e70-881f-d67d7fe8acfd",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9c55e2c7-2ced-4d00-8554-25c39aad7bbb" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c55e2c7-2ced-4d00-8554-25c39aad7bbb")) {                    Plotly.newPlot(                        "9c55e2c7-2ced-4d00-8554-25c39aad7bbb",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cdeb8542-4eed-4182-9870-b53830dba25d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdeb8542-4eed-4182-9870-b53830dba25d")) {                    Plotly.newPlot(                        "cdeb8542-4eed-4182-9870-b53830dba25d",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="af04a353-958e-4deb-a0dd-971dafe4fc69" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af04a353-958e-4deb-a0dd-971dafe4fc69")) {                    Plotly.newPlot(                        "af04a353-958e-4deb-a0dd-971dafe4fc69",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="89d1a731-38c9-49a1-b6f6-71ebb4e80787" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89d1a731-38c9-49a1-b6f6-71ebb4e80787")) {                    Plotly.newPlot(                        "89d1a731-38c9-49a1-b6f6-71ebb4e80787",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="186fbcfa-d53e-4572-a53c-9e0136f9b53a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("186fbcfa-d53e-4572-a53c-9e0136f9b53a")) {                    Plotly.newPlot(                        "186fbcfa-d53e-4572-a53c-9e0136f9b53a",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":"" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7a7258f-34d7-4882-9411-cede3fb93042" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7a7258f-34d7-4882-9411-cede3fb93042")) {                    Plotly.newPlot(                        "d7a7258f-34d7-4882-9411-cede3fb93042",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="325ba1be-f80c-4ede-9c73-c3d17c751380" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("325ba1be-f80c-4ede-9c73-c3d17c751380")) {                    Plotly.newPlot(                        "325ba1be-f80c-4ede-9c73-c3d17c751380",                        [],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
import pandas as pd
import plotly.express as px

# กำหนดช่วงราคา
price_ranges = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-1000', '1001-2000', '2001-3000', '3001-4000', '4001-5000', '5001-10000', '10000+']

# สร้างกราฟสำหรับแต่ละช่วงราคา
for price_range in price_ranges:
    # กรองข้อมูลเฉพาะข้อมูลในช่วงราคา
    if price_range == '10000+':
        df_price_range = df_pay_true[df_pay_true['price'] >= 10000]
    else:
        price_range_min, price_range_max = map(int, price_range.split('-'))
        df_price_range = df_pay_true[(df_pay_true['price'] >= price_range_min) & (df_pay_true['price'] <= price_range_max)]

    # รวมยอดรวมของราคาตามวันของสัปดาห์
    df_grouped = df_price_range.groupby('day_of_week')['price'].sum().reset_index()

    # เรียงลำดับค่าราคารวมจากมากไปน้อย
    df_grouped_sorted = df_grouped.sort_values(by='price', ascending=False)

    # สร้างกราฟแท่งด้วย Plotly Express
    fig = px.bar(df_grouped_sorted,
                 x='day_of_week',  # ให้แกน x เป็นวันของสัปดาห์
                 y='price',  # ให้แกน y เป็นยอดรวมของราคา
                 labels={'day_of_week': 'Day of Week', 'price': 'Total Price'},  # กำหนด label ให้แกน x และ y
                 title=f'Total Price by day_of_week (Price Range {price_range})',
                 color='day_of_week',  # ใช้วันของสัปดาห์เป็นสี
                 color_discrete_map=color_map  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
    )

    # เพิ่ม label ให้กับแกน x และ y
    fig.update_xaxes(title_text='Day of Week')
    fig.update_yaxes(title_text='Total Price')

    # กำหนดขนาดของกราฟ
    fig.update_layout(width=800, height=600)

    # เพิ่มตัวเลขกำกับในกราฟแต่ละแท่ง
    for bar in fig.data:
        for i, j in enumerate(bar.y):
            text = f'{j:.0f}'  # แสดงทศนิยม 0 หลัก
            fig.add_annotation(
                x=bar.x[i],
                y=j,
                text=text,
                textangle=0,
                showarrow=False,
                font_size=12,
            )

    # แสดงกราฟ
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6e70774c-db23-4326-89bf-fee854bf5adc" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e70774c-db23-4326-89bf-fee854bf5adc")) {                    Plotly.newPlot(                        "6e70774c-db23-4326-89bf-fee854bf5adc",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[47398.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[44230.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[40227.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[38669.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[36757.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[30246.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[29362.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c98b90ef-806a-4257-851c-65ba4e03bb4e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c98b90ef-806a-4257-851c-65ba4e03bb4e")) {                    Plotly.newPlot(                        "c98b90ef-806a-4257-851c-65ba4e03bb4e",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[59348.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[56226.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[53599.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[53252.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[46609.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[42088.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[35198.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5a8e1969-bb44-49c3-b785-89afdf2bcd27" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a8e1969-bb44-49c3-b785-89afdf2bcd27")) {                    Plotly.newPlot(                        "5a8e1969-bb44-49c3-b785-89afdf2bcd27",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[3143.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[2604.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[2594.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[2183.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[1542.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[1478.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[1227.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4b4a61e2-3af5-4bc8-8018-056c0ae9918d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b4a61e2-3af5-4bc8-8018-056c0ae9918d")) {                    Plotly.newPlot(                        "4b4a61e2-3af5-4bc8-8018-056c0ae9918d",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[46134.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[40191.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[37092.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[34946.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[31864.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[25863.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[21294.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bc50abff-620e-4124-99e1-9d849f38186c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc50abff-620e-4124-99e1-9d849f38186c")) {                    Plotly.newPlot(                        "bc50abff-620e-4124-99e1-9d849f38186c",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[2632.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[2050.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[1729.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[820.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[410.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[410.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[410.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="64582d46-c8ae-4533-8ab0-bebbd9b4b5ee" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64582d46-c8ae-4533-8ab0-bebbd9b4b5ee")) {                    Plotly.newPlot(                        "64582d46-c8ae-4533-8ab0-bebbd9b4b5ee",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[12938.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[12198.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[10203.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[10035.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[8594.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[8401.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[6401.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="60d8e835-33ba-4ab9-ba48-f081f4a056b9" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60d8e835-33ba-4ab9-ba48-f081f4a056b9")) {                    Plotly.newPlot(                        "60d8e835-33ba-4ab9-ba48-f081f4a056b9",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[9204.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[8105.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[8014.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sunday","marker":{"color":"hsl(0, 70%, 70%)","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":["Sunday"],"xaxis":"x","y":[7905.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[7706.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[3608.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[2798.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8f274ff-5385-4d59-bd1e-fb99c9719259" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8f274ff-5385-4d59-bd1e-fb99c9719259")) {                    Plotly.newPlot(                        "d8f274ff-5385-4d59-bd1e-fb99c9719259",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[2509.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[2509.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[2499.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[2499.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[2499.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b157bf2d-27c9-4752-810d-b67d00b018b6" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b157bf2d-27c9-4752-810d-b67d00b018b6")) {                    Plotly.newPlot(                        "b157bf2d-27c9-4752-810d-b67d00b018b6",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[6610.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Saturday","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":["Saturday"],"xaxis":"x","y":[3310.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewi ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="79740a4e-b59b-4035-a02c-2407fa5ebe5e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79740a4e-b59b-4035-a02c-2407fa5ebe5e")) {                    Plotly.newPlot(                        "79740a4e-b59b-4035-a02c-2407fa5ebe5e",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[9998.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Friday","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Friday","offsetgroup":"Friday","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday"],"xaxis":"x","y":[4999.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8174b680-b178-42b8-8c10-c944c30db02b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8174b680-b178-42b8-8c10-c944c30db02b")) {                    Plotly.newPlot(                        "8174b680-b178-42b8-8c10-c944c30db02b",                        [{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":["Monday"],"xaxis":"x","y":[19800.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thursday","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":["Thursday"],"xaxis":"x","y":[9999.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"hsl(330, 70%, 70%)","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Tuesday"],"xaxis":"x","y":[9999.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Day of Week=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"hsl(120, 70%, 70%)","pattern":{"shape":""}},"name":"Wednesday","offsetgroup":"Wednesday","orientation":"v","showlegend":true,"textposition":"auto","x":["Wednesday"],"xaxis":"x","y":[5009.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="55afa06b-8ba6-4a6f-918f-6de1d288d526" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55afa06b-8ba6-4a6f-918f-6de1d288d526")) {                    Plotly.newPlot(                        "55afa06b-8ba6-4a6f-918f-6de1d288d526",                        [],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
color_time = {
    'Morning': 'hsl(60, 70%, 70%)',  # เหลือง
    'Afternoon': 'hsl(30, 70%, 70%)',  # ส้ม
    'Evening': 'hsl(240, 70%, 70%)',  # ฟ้า
    'Night': 'hsl(270, 70%, 70%)',  # ม่วง

}

# %%
import plotly.express as px

# รวมและเรียงข้อมูลตามช่วงเวลา
df_sorted = df_pay_true['time_range'].value_counts().sort_values(ascending=False).reset_index()
df_sorted.columns = ['Time Range', 'Count']

# สร้างข้อความที่ต้องการแสดงในแต่ละแท่งกราฟ
text_data = [f"{count}" for count in df_sorted['Count']]

# สร้างกราฟแท่งด้วย Plotly Express
fig = px.bar(df_sorted,
             x='Time Range',  # ให้แกน x เป็นช่วงเวลา
             y='Count',  # ให้แกน y เป็นจำนวนการเกิดขึ้น
             labels={'Time Range': 'Time Range', 'Count': 'Count'},  # กำหนด label ให้แกน x และ y
             title='Count of Entries by Time Range',
             text=text_data,  # เพิ่มข้อความ
             color='Time Range',  # ใช้ช่วงเวลาเป็นสี
             color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
             )

# เพิ่ม label ให้กับแกน x และ y
fig.update_xaxes(title_text='Time Range')
fig.update_yaxes(title_text='Count')

# กำหนดขนาดของกราฟ
fig.update_layout(width=800, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35808e87-4287-414b-82a9-6a315f2e7791" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35808e87-4287-414b-82a9-6a315f2e7791")) {                    Plotly.newPlot(                        "35808e87-4287-414b-82a9-6a315f2e7791",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"text":["2758"],"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[2758],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"text":["1986"],"textposition":"auto","x":["Evening"],"xaxis":"x","y":[1986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"text":["1748"],"textposition":"auto","x":["Morning"],"xaxis":"x","y":[1748],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"text":["715"],"textposition":"auto","x":["Night"],"xaxis":"x","y":[715],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks" ...

# %%
import pandas as pd
import plotly.express as px

# กำหนดช่วงราคา
price_ranges = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-1000', '1001-2000', '2001-3000', '3001-4000', '4001-5000', '5001-10000', '10000+']

# สร้างกราฟสำหรับแต่ละช่วงราคา
for price_range in price_ranges:
    # กรองข้อมูลเฉพาะข้อมูลในช่วงราคา
    if price_range == '10000+':
        df_price_range = df_pay_true[df_pay_true['price'] >= 10000]
    else:
        price_range_min, price_range_max = map(int, price_range.split('-'))
        df_price_range = df_pay_true[(df_pay_true['price'] >= price_range_min) & (df_pay_true['price'] <= price_range_max)]

    # รวมยอดรวมของราคาตามช่วงเวลา
    df_grouped = df_price_range.groupby('time_range')['price'].sum().reset_index()

    # เรียงลำดับค่าราคารวมจากมากไปน้อย
    df_grouped_sorted = df_grouped.sort_values(by='price', ascending=False)

    # สร้างกราฟแท่งด้วย Plotly Express
    fig = px.bar(df_grouped_sorted,
                 x='time_range',  # ให้แกน x เป็นช่วงเวลา
                 y='price',  # ให้แกน y เป็นยอดรวมของราคา
                 labels={'time_range': 'Time Range', 'price': 'Total Price'},  # กำหนด label ให้แกน x และ y
                 title=f'Total Price by time_range (Price Range {price_range})',
                 color='time_range',  # ใช้ช่วงเวลาเป็นสี
                 color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
    )

    # เพิ่ม label ให้กับแกน x และ y
    fig.update_xaxes(title_text='Time Range')
    fig.update_yaxes(title_text='Total Price')

    # กำหนดขนาดของกราฟ
    fig.update_layout(width=800, height=600)

    # เพิ่มตัวเลขกำกับในกราฟแต่ละแท่ง
    for bar in fig.data:
        for i, j in enumerate(bar.y):
            text = f'{j:.0f}'  # แสดงทศนิยม 0 หลัก
            fig.add_annotation(
                x=bar.x[i],
                y=j,
                text=text,
                textangle=0,
                showarrow=False,
                font_size=12,
            )

    # แสดงกราฟ
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac52e017-49fa-4ad4-99a1-c9b16377374b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac52e017-49fa-4ad4-99a1-c9b16377374b")) {                    Plotly.newPlot(                        "ac52e017-49fa-4ad4-99a1-c9b16377374b",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[102463.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[81679.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[59166.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[23581.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="03657dd9-e5b5-4a25-b1d6-2a4b8ecc7759" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03657dd9-e5b5-4a25-b1d6-2a4b8ecc7759")) {                    Plotly.newPlot(                        "03657dd9-e5b5-4a25-b1d6-2a4b8ecc7759",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[139622.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[101264.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[77587.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[27847.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="28097bf3-f55d-42b8-a401-59bb968a0721" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28097bf3-f55d-42b8-a401-59bb968a0721")) {                    Plotly.newPlot(                        "28097bf3-f55d-42b8-a401-59bb968a0721",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[6239.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[3755.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[2803.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[1974.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1e09a62d-dbad-4bf5-b692-8b848d93a88e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e09a62d-dbad-4bf5-b692-8b848d93a88e")) {                    Plotly.newPlot(                        "1e09a62d-dbad-4bf5-b692-8b848d93a88e",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[89491.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[76568.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[53645.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[17680.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ab30f5ae-96ee-400a-9f72-1f17c186c1fb" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab30f5ae-96ee-400a-9f72-1f17c186c1fb")) {                    Plotly.newPlot(                        "ab30f5ae-96ee-400a-9f72-1f17c186c1fb",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[3131.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[2870.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[2050.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[410.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="85fe06e2-75f2-47e0-9995-1367e2cd8418" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85fe06e2-75f2-47e0-9995-1367e2cd8418")) {                    Plotly.newPlot(                        "85fe06e2-75f2-47e0-9995-1367e2cd8418",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[33750.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[15604.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[14020.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[5396.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="830b1f7f-5905-4ca2-9d0c-430e7aababfd" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("830b1f7f-5905-4ca2-9d0c-430e7aababfd")) {                    Plotly.newPlot(                        "830b1f7f-5905-4ca2-9d0c-430e7aababfd",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[22096.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[14121.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[5917.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"hsl(270, 70%, 70%)","pattern":{"shape":""}},"name":"Night","offsetgroup":"Night","orientation":"v","showlegend":true,"textposition":"auto","x":["Night"],"xaxis":"x","y":[5206.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1bc036f5-befc-4387-8f0d-4b25a7e72138" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bc036f5-befc-4387-8f0d-4b25a7e72138")) {                    Plotly.newPlot(                        "1bc036f5-befc-4387-8f0d-4b25a7e72138",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[7507.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[5008.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="331eb94b-8dc5-4f71-a100-6420caac1283" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("331eb94b-8dc5-4f71-a100-6420caac1283")) {                    Plotly.newPlot(                        "331eb94b-8dc5-4f71-a100-6420caac1283",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[3310.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[3310.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[3300.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="37184dc4-8d1b-43d2-8800-6e6613101fe3" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37184dc4-8d1b-43d2-8800-6e6613101fe3")) {                    Plotly.newPlot(                        "37184dc4-8d1b-43d2-8800-6e6613101fe3",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[9998.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[4999.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidt ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0ea9c82a-17c4-4a55-b3fb-d4cbb6b749d5" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ea9c82a-17c4-4a55-b3fb-d4cbb6b749d5")) {                    Plotly.newPlot(                        "0ea9c82a-17c4-4a55-b3fb-d4cbb6b749d5",                        [{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"hsl(60, 70%, 70%)","pattern":{"shape":""}},"name":"Morning","offsetgroup":"Morning","orientation":"v","showlegend":true,"textposition":"auto","x":["Morning"],"xaxis":"x","y":[24809.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"hsl(30, 70%, 70%)","pattern":{"shape":""}},"name":"Afternoon","offsetgroup":"Afternoon","orientation":"v","showlegend":true,"textposition":"auto","x":["Afternoon"],"xaxis":"x","y":[9999.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Time Range=%{x}\u003cbr\u003eTotal Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"hsl(240, 70%, 70%)","pattern":{"shape":""}},"name":"Evening","offsetgroup":"Evening","orientation":"v","showlegend":true,"textposition":"auto","x":["Evening"],"xaxis":"x","y":[9999.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3cb1a9c9-5364-44b3-a107-80cf06eb243f" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cb1a9c9-5364-44b3-a107-80cf06eb243f")) {                    Plotly.newPlot(                        "3cb1a9c9-5364-44b3-a107-80cf06eb243f",                        [],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# #จำนวนเเพ็คที่ผู้ใช้แบบจ่ายเงินซื้อ

# %%
import plotly.express as px

# รวมและเรียงข้อมูลตามช่วงเวลา
df_sorted = df_pay_true['package_id'].value_counts().sort_values(ascending=False).reset_index()
df_sorted.columns = ['Package ID', 'Count']

# สร้างข้อความที่ต้องการแสดงในแต่ละแท่งกราฟ
text_data = [f"{count}" for count in df_sorted['Count']]

# สร้างกราฟแท่งด้วย Plotly Express
fig = px.bar(df_sorted,
             x='Package ID',  # ให้แกน x เป็นช่วงเวลา
             y='Count',  # ให้แกน y เป็นจำนวนการเกิดขึ้น
             labels={'Package ID': 'Package ID', 'Count': 'Count'},  # กำหนด label ให้แกน x และ y
             title='Count of Entries by Package ID',
             text=text_data,  # เพิ่มข้อความ
             color='Package ID',  # ใช้ช่วงเวลาเป็นสี
             color_discrete_map=color_time  # กำหนดสีตามค่าที่กำหนดไว้ใน color_map
             )

# เพิ่ม label ให้กับแกน x และ y
fig.update_xaxes(title_text='Package ID')
fig.update_yaxes(title_text='Count')

# กำหนดขนาดของกราฟ
fig.update_layout(width=1000, height=600)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="12e65522-b385-4c93-9b7e-90e44cf1b86e" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12e65522-b385-4c93-9b7e-90e44cf1b86e")) {                    Plotly.newPlot(                        "12e65522-b385-4c93-9b7e-90e44cf1b86e",                        [{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"credit","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"credit","offsetgroup":"credit","orientation":"v","showlegend":true,"text":["3138"],"textposition":"auto","x":["credit"],"xaxis":"x","y":[3138],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_299","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"pack_299","offsetgroup":"pack_299","orientation":"v","showlegend":true,"text":["1707"],"textposition":"auto","x":["pack_299"],"xaxis":"x","y":[1707],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_99","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"pack_99","offsetgroup":"pack_99","orientation":"v","showlegend":true,"text":["1546"],"textposition":"auto","x":["pack_99"],"xaxis":"x","y":[1546],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_750","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"pack_750","offsetgroup":"pack_750","orientation":"v","showlegend":true,"text":["336"],"textposition":"auto","x":["pack_750"],"xaxis":"x","y":[336],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_499","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"pack_499","offsetgroup":"pack_499","orientation":"v","showlegend":true,"text":["183"],"textposition":"auto","x":["pack_499"],"xaxis":"x","y":[183],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_600","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"pack_600","offsetgroup":"pack_600","orientation":"v","showlegend":true,"text":["140"],"textposition":"auto","x":["pack_600"],"xaxis":"x","y":[140],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_599","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"pack_599","offsetgroup":"pack_599","orientation":"v","showlegend":true,"text":["70"],"textposition":"auto","x":["pack_599"],"xaxis":"x","y":[70],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_2000","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"pack_2000","offsetgroup":"pack_2000","orientation":"v","showlegend":true,"text":["31"],"textposition":"auto","x":["pack_2000"],"xaxis":"x","y":[31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Package ID=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pack_1699","marker": ...

# %%
# แปลงคอลัมน์ datetime เป็น string
df_msg['datetime'] = df_msg['datetime'].astype(str)

# แยกวันที่และเวลาออกจากกัน
df_msg['datetime'] = df_msg['datetime'].str.split(' ')

# เก็บเฉพาะวันที่
df_msg['date'] = df_msg['datetime'].str[0]

# เก็บเฉพาะเวลา
df_msg['time'] = df_msg['datetime'].str[1]

# แปลงวันที่เป็นรูปแบบ datetime
df_msg['date'] = pd.to_datetime(df_msg['date'])

# แปลงเวลาเป็นรูปแบบ datetime
df_msg['time'] = pd.to_datetime(df_msg['time'])

# ตัดมิลลิวินาทีออกจากเวลา
df_msg['time'] = df_msg['time'].dt.floor('s')

# รวมmsgวันที่และเวลาเข้าด้วยกัน
df_msg['datetime'] = pd.to_datetime(df_msg['date'].dt.strftime('%Y-%m-%d') + ' ' + df_msg['time'].dt.strftime('%H:%M:%S'))

# ลบ columns 'date' และ 'time' ที่ไม่จำเป็น
df_msg.drop(columns=['date', 'time'], inplace=True)

df_msg
# Out:
# <ipython-input-37-5d83834b2773>:17: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#                               _id                            user_id  \
# 0        612e4174bda79b4dffbfeb84  U8530610030c64cc1843fd0f95b5f2758
# 1        612e4174952575b7a2c366c1  U8530610030c64cc1843fd0f95b5f2758
# 2        612e41749ac449ff6262dcc0  U8530610030c64cc1843fd0f95b5f2758
# 3        612e4174ea19c311d95c33b2  U8530610030c64cc1843fd0f95b5f2758
# 4        612e4174bda79b4dffbfeb85  U8530610030c64cc1843fd0f95b5f2758
# ...                           ...                                ...
# 3309847  6617c2d41133cbc3e61ba060       li7WxCoa9LdwGLhmzrFilsjUCsu1
# 3309848  6617c2d5c8c16df47362cc67       Burd7NHMZvZwWQIjj114Z3gpIqA3
# 3309849  6617c2d7a3dddc8cf3cff22d  U591e3bd8bb1108c417696f11a0ad1911
# 3309850  6617c2de6463d2b14340d925       osNbSUtz0YZqr6V09WWcPmbuaYQ2
# 3309851  6617c2e5a3958e3769a607e7       kiNTFaWLKjVCYeriITipN2yPkhx1
#
#                                                    message  \
# 0                                               สวัสดีครับ
# 1                                               สวัสดีครับ
# 2                                               สวัสดีครับ
# 3                                               สวัสดีครับ
# 4                                               สวัสดีครับ
# ...                                                    ...
# 3309847  สวัสดีเช้าวันศุกร์ที่12เมษายน2567พบกันเช่นเคยก...
# 3309848  คำถามที่ 2\nบัวลอยใบเตยทำอย่างไร\nเด็ก ๆ ร่วมก...
# 3309849  กดครับ....ถ้าเราจะเอาริงค์เฟรมเข้าเราจะต้องกดส...
# 3309850                   ตำนานท้าวเวสสุวันโดยตำนานสามพิพบ
# 3309851  หลังจากที่TikTokและYoutubeได้ติดป้ายกำกับคอนเท...
#
#                    datetime   channel count speaker  url audio_id    page  \
# 0       2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN     NaN
# 1       2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN     NaN
# 2       2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN     NaN
# 3       2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN     NaN
# 4       2021-08-31 21:49:24       NaN   NaN     NaN  NaN      NaN     NaN
# ...                     ...       ...   ...     ...  ...      ...     ...
# 3309847 2024-04-11 18:00:36      play   346   perce  NaN    INUIZ  studio
# 3309848 2024-04-11 18:00:37  download   160       1  NaN      NaN     NaN
# 3309849 2024-04-11 18:00:39      play    67    kong  NaN    OQJOE  studio
# 3309850 2024-04-11 18:00:46  download    32  flower  NaN    DJVZE     NaN
# 3309851 2024-04-11 18:00:53  download   259  jaonai  NaN    BGTLL     NaN
#
#         provider
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3309847      NaN
# 3309848    canva
# 3309849      NaN
# 3309850      NaN
# 3309851      NaN
#
# [3309852 rows x 11 columns]

# %%
df_msg2 = df_msg[df_msg['datetime'].dt.year >= 2024]

# กรองเอาเฉพาะตั้งเเต่เดือน 2 ปี 2024
df_msg2 = df_msg2[df_msg2['datetime'].dt.month >= 2]

df_msg2
# Out:
#                               _id                            user_id  \
# 2095450  65d0948df281dda53fd6d31f  U69019814430a41adf5b58c0478022744
# 2095451  65d094952869e9a28f087a44  U69019814430a41adf5b58c0478022744
# 2095452  65d094a173574e4954ff1c7d       vo0zwSLT4rPBCeNyAmBe1PVsiJl1
# 2095453  65d094b8f9bd7a3f14151fbd       vo0zwSLT4rPBCeNyAmBe1PVsiJl1
# 2095454  65d094b9821dc3a90d441f75  Uddb4c3f85e14a10c53e9b819d6ff7f6e
# ...                           ...                                ...
# 3309847  6617c2d41133cbc3e61ba060       li7WxCoa9LdwGLhmzrFilsjUCsu1
# 3309848  6617c2d5c8c16df47362cc67       Burd7NHMZvZwWQIjj114Z3gpIqA3
# 3309849  6617c2d7a3dddc8cf3cff22d  U591e3bd8bb1108c417696f11a0ad1911
# 3309850  6617c2de6463d2b14340d925       osNbSUtz0YZqr6V09WWcPmbuaYQ2
# 3309851  6617c2e5a3958e3769a607e7       kiNTFaWLKjVCYeriITipN2yPkhx1
#
#                                                    message  \
# 2095450  รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095451  รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095452  โดนใจทาสแมวแบบสุดสุดจ้าโซฟาน้องแมวผ้าขนนุ่มนิ่...
# 2095453  โดนใจทาสแมวแบบสุดสุดไปเลยจ้านี่เลยโซฟาน้องแมวผ...
# 2095454                    เจ้าของช่อดอกไม้ในมือเบลล่าราณี
# ...                                                    ...
# 3309847  สวัสดีเช้าวันศุกร์ที่12เมษายน2567พบกันเช่นเคยก...
# 3309848  คำถามที่ 2\nบัวลอยใบเตยทำอย่างไร\nเด็ก ๆ ร่วมก...
# 3309849  กดครับ....ถ้าเราจะเอาริงค์เฟรมเข้าเราจะต้องกดส...
# 3309850                   ตำนานท้าวเวสสุวันโดยตำนานสามพิพบ
# 3309851  หลังจากที่TikTokและYoutubeได้ติดป้ายกำกับคอนเท...
#
#                    datetime   channel count   speaker  url audio_id    page  \
# 2095450 2024-02-17 18:12:13      play   150        bo  NaN    BPRSV  studio
# 2095451 2024-02-17 18:12:21      play   150        bo  NaN    OVCLD  studio
# 2095452 2024-02-17 18:12:33      play   153       pla  NaN    ZDEBT  studio
# 2095453 2024-02-17 18:12:56      play   164       pla  NaN    ZDEBT  studio
# 2095454 2024-02-17 18:12:57      play    31  tonkhaow  NaN    MHJLT  studio
# ...                     ...       ...   ...       ...  ...      ...     ...
# 3309847 2024-04-11 18:00:36      play   346     perce  NaN    INUIZ  studio
# 3309848 2024-04-11 18:00:37  download   160         1  NaN      NaN     NaN
# 3309849 2024-04-11 18:00:39      play    67      kong  NaN    OQJOE  studio
# 3309850 2024-04-11 18:00:46  download    32    flower  NaN    DJVZE     NaN
# 3309851 2024-04-11 18:00:53  download   259    jaonai  NaN    BGTLL     NaN
#
#         provider
# 2095450      NaN
# 2095451      NaN
# 2095452      NaN
# 2095453      NaN
# 2095454      NaN
# ...          ...
# 3309847      NaN
# 3309848    canva
# 3309849      NaN
# 3309850      NaN
# 3309851      NaN
#
# [1214402 rows x 11 columns]

# %%
# ลบแถวที่ซ้ำกัน
df_msg2 = df_msg2.drop_duplicates(subset=['user_id', 'message', 'datetime'], keep='first')

df_msg2
# Out:
#                               _id                            user_id  \
# 2095450  65d0948df281dda53fd6d31f  U69019814430a41adf5b58c0478022744
# 2095451  65d094952869e9a28f087a44  U69019814430a41adf5b58c0478022744
# 2095452  65d094a173574e4954ff1c7d       vo0zwSLT4rPBCeNyAmBe1PVsiJl1
# 2095453  65d094b8f9bd7a3f14151fbd       vo0zwSLT4rPBCeNyAmBe1PVsiJl1
# 2095454  65d094b9821dc3a90d441f75  Uddb4c3f85e14a10c53e9b819d6ff7f6e
# ...                           ...                                ...
# 3309847  6617c2d41133cbc3e61ba060       li7WxCoa9LdwGLhmzrFilsjUCsu1
# 3309848  6617c2d5c8c16df47362cc67       Burd7NHMZvZwWQIjj114Z3gpIqA3
# 3309849  6617c2d7a3dddc8cf3cff22d  U591e3bd8bb1108c417696f11a0ad1911
# 3309850  6617c2de6463d2b14340d925       osNbSUtz0YZqr6V09WWcPmbuaYQ2
# 3309851  6617c2e5a3958e3769a607e7       kiNTFaWLKjVCYeriITipN2yPkhx1
#
#                                                    message  \
# 2095450  รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095451  รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095452  โดนใจทาสแมวแบบสุดสุดจ้าโซฟาน้องแมวผ้าขนนุ่มนิ่...
# 2095453  โดนใจทาสแมวแบบสุดสุดไปเลยจ้านี่เลยโซฟาน้องแมวผ...
# 2095454                    เจ้าของช่อดอกไม้ในมือเบลล่าราณี
# ...                                                    ...
# 3309847  สวัสดีเช้าวันศุกร์ที่12เมษายน2567พบกันเช่นเคยก...
# 3309848  คำถามที่ 2\nบัวลอยใบเตยทำอย่างไร\nเด็ก ๆ ร่วมก...
# 3309849  กดครับ....ถ้าเราจะเอาริงค์เฟรมเข้าเราจะต้องกดส...
# 3309850                   ตำนานท้าวเวสสุวันโดยตำนานสามพิพบ
# 3309851  หลังจากที่TikTokและYoutubeได้ติดป้ายกำกับคอนเท...
#
#                    datetime   channel count   speaker  url audio_id    page  \
# 2095450 2024-02-17 18:12:13      play   150        bo  NaN    BPRSV  studio
# 2095451 2024-02-17 18:12:21      play   150        bo  NaN    OVCLD  studio
# 2095452 2024-02-17 18:12:33      play   153       pla  NaN    ZDEBT  studio
# 2095453 2024-02-17 18:12:56      play   164       pla  NaN    ZDEBT  studio
# 2095454 2024-02-17 18:12:57      play    31  tonkhaow  NaN    MHJLT  studio
# ...                     ...       ...   ...       ...  ...      ...     ...
# 3309847 2024-04-11 18:00:36      play   346     perce  NaN    INUIZ  studio
# 3309848 2024-04-11 18:00:37  download   160         1  NaN      NaN     NaN
# 3309849 2024-04-11 18:00:39      play    67      kong  NaN    OQJOE  studio
# 3309850 2024-04-11 18:00:46  download    32    flower  NaN    DJVZE     NaN
# 3309851 2024-04-11 18:00:53  download   259    jaonai  NaN    BGTLL     NaN
#
#         provider
# 2095450      NaN
# 2095451      NaN
# 2095452      NaN
# 2095453      NaN
# 2095454      NaN
# ...          ...
# 3309847      NaN
# 3309848    canva
# 3309849      NaN
# 3309850      NaN
# 3309851      NaN
#
# [1213245 rows x 11 columns]

# %%
len(df_msg)
# Out:
# 3309852

# %%
len(df_msg2)
# Out:
# 1213245

# %%
# ตรวจสอบประเภทข้อมูล
print(df_msg2['message'].dtypes)

# ตรวจสอบค่า null
print(df_msg2['message'].isnull().sum())

# ตรวจสอบตัวอย่างข้อมูล
print(df_msg2['message'].head())

df_msg2
# Out:
# object
# 0
# 2095450    รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095451    รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095452    โดนใจทาสแมวแบบสุดสุดจ้าโซฟาน้องแมวผ้าขนนุ่มนิ่...
# 2095453    โดนใจทาสแมวแบบสุดสุดไปเลยจ้านี่เลยโซฟาน้องแมวผ...
# 2095454                      เจ้าของช่อดอกไม้ในมือเบลล่าราณี
# Name: message, dtype: object
#                               _id                            user_id  \
# 2095450  65d0948df281dda53fd6d31f  U69019814430a41adf5b58c0478022744
# 2095451  65d094952869e9a28f087a44  U69019814430a41adf5b58c0478022744
# 2095452  65d094a173574e4954ff1c7d       vo0zwSLT4rPBCeNyAmBe1PVsiJl1
# 2095453  65d094b8f9bd7a3f14151fbd       vo0zwSLT4rPBCeNyAmBe1PVsiJl1
# 2095454  65d094b9821dc3a90d441f75  Uddb4c3f85e14a10c53e9b819d6ff7f6e
# ...                           ...                                ...
# 3309847  6617c2d41133cbc3e61ba060       li7WxCoa9LdwGLhmzrFilsjUCsu1
# 3309848  6617c2d5c8c16df47362cc67       Burd7NHMZvZwWQIjj114Z3gpIqA3
# 3309849  6617c2d7a3dddc8cf3cff22d  U591e3bd8bb1108c417696f11a0ad1911
# 3309850  6617c2de6463d2b14340d925       osNbSUtz0YZqr6V09WWcPmbuaYQ2
# 3309851  6617c2e5a3958e3769a607e7       kiNTFaWLKjVCYeriITipN2yPkhx1
#
#                                                    message  \
# 2095450  รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095451  รับซ่อมคอมทั่วราชอาณาจักรไม่ว่าจะเป็นการอัพเกร...
# 2095452  โดนใจทาสแมวแบบสุดสุดจ้าโซฟาน้องแมวผ้าขนนุ่มนิ่...
# 2095453  โดนใจทาสแมวแบบสุดสุดไปเลยจ้านี่เลยโซฟาน้องแมวผ...
# 2095454                    เจ้าของช่อดอกไม้ในมือเบลล่าราณี
# ...                                                    ...
# 3309847  สวัสดีเช้าวันศุกร์ที่12เมษายน2567พบกันเช่นเคยก...
# 3309848  คำถามที่ 2\nบัวลอยใบเตยทำอย่างไร\nเด็ก ๆ ร่วมก...
# 3309849  กดครับ....ถ้าเราจะเอาริงค์เฟรมเข้าเราจะต้องกดส...
# 3309850                   ตำนานท้าวเวสสุวันโดยตำนานสามพิพบ
# 3309851  หลังจากที่TikTokและYoutubeได้ติดป้ายกำกับคอนเท...
#
#                    datetime   channel count   speaker  url audio_id    page  \
# 2095450 2024-02-17 18:12:13      play   150        bo  NaN    BPRSV  studio
# 2095451 2024-02-17 18:12:21      play   150        bo  NaN    OVCLD  studio
# 2095452 2024-02-17 18:12:33      play   153       pla  NaN    ZDEBT  studio
# 2095453 2024-02-17 18:12:56      play   164       pla  NaN    ZDEBT  studio
# 2095454 2024-02-17 18:12:57      play    31  tonkhaow  NaN    MHJLT  studio
# ...                     ...       ...   ...       ...  ...      ...     ...
# 3309847 2024-04-11 18:00:36      play   346     perce  NaN    INUIZ  studio
# 3309848 2024-04-11 18:00:37  download   160         1  NaN      NaN     NaN
# 3309849 2024-04-11 18:00:39      play    67      kong  NaN    OQJOE  studio
# 3309850 2024-04-11 18:00:46  download    32    flower  NaN    DJVZE     NaN
# 3309851 2024-04-11 18:00:53  download   259    jaonai  NaN    BGTLL     NaN
#
#         provider
# 2095450      NaN
# 2095451      NaN
# 2095452      NaN
# 2095453      NaN
# 2095454      NaN
# ...          ...
# 3309847      NaN
# 3309848    canva
# 3309849      NaN
# 3309850      NaN
# 3309851      NaN
#
# [1213245 rows x 11 columns]
